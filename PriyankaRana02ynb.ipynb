# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankarana5650-commits/PriyankaRana/blob/main/PriyankaRana02ynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[2,5,1,9,2,0,0,7]
a.append(10)
print(a)
print(a[1])
print(a[0:4])
print(a[-5:-1])
print(a[-1])
# Out:
# [2, 5, 1, 9, 2, 0, 0, 7, 10]
# 5
# [2, 5, 1, 9]
# [2, 0, 0, 7]
# 10

# %%
a=[200,500,400,300]
sum=0
for i in a:
  sum=sum+i
print(sum)
# Out:
# 1400
